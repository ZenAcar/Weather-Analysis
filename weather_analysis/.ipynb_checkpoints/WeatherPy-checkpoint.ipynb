# %% [markdown]
# # WeatherPy
# ----

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from scipy import stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
params = {
    "appid": weather_api_key,
    "q": "city",
    "units": "metric"
}

response = requests.get(url, params)
print(response.url)
response.json()
    
data= response.json()

print(json.dumps(data, indent=4))
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=e61334b19fef09307be75f8ae2ff82d9&q=city&units=metric
# {
#     "coord": {
#         "lon": 149.13,
#         "lat": -35.28
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 14.89,
#         "feels_like": 12.08,
#         "temp_min": 14.44,
#         "temp_max": 15,
#         "pressure": 1025,
#         "humidity": 54
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.6,
#         "deg": 350
#     },
#     "clouds": {
#         "all": 32
#     },
#     "dt": 1601342700,
#     "sys": {
#         "type": 1,
#         "id": 9588,
#         "country": "AU",
#         "sunrise": 1601322169,
#         "sunset": 1601366683
#     },
#     "timezone": 36000,
#     "id": 2172517,
#     "name": "City",
#     "cod": 200
# }

# %%
#Create a dictionary to store the data
data = {
    "City":[],
    "Cloudiness":[],
    "Country":[],
    "Date":[],
    "Humidity":[],
    "Lat":[],
    "Lng":[],
    "Max Temp":[],
    "Wind Speed":[]
}
count = 1

# %%
print("Beginning Data Retrieval")
print('-----------------------------')
for city in cities:
    print(f"Processing Record {count} | {city}")
    params["q"] = city
    response = requests.get(url,params).json()
    
    if response["cod"] == "404":
        print("City not found. Try another city...")
    else:
        data["City"].append(city)
        data["Cloudiness"].append(response["clouds"]["all"])
        data["Country"].append(response["sys"]["country"])
        data["Date"].append(response["dt"])
        data["Humidity"].append(response["main"]["humidity"])
        data["Lat"].append(response["coord"]["lat"])
        data["Lng"].append(response["coord"]["lon"])
        data["Max Temp"].append(response["main"]["temp_max"])
        data["Wind Speed"].append(response["wind"]["speed"])
    count += 1
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | ponta do sol
# Processing Record 2 | vaitupu
# City not found. Try another city...
# Processing Record 3 | busselton
# Processing Record 4 | ciras
# City not found. Try another city...
# Processing Record 5 | albany
# Processing Record 6 | cape town
# Processing Record 7 | zhigansk
# Processing Record 8 | yellowknife
# Processing Record 9 | tera
# Processing Record 10 | bluff
# Processing Record 11 | upernavik
# Processing Record 12 | hermanus
# Processing Record 13 | avarua
# Processing Record 14 | fare
# Processing Record 15 | banda aceh
# Processing Record 16 | mahebourg
# Processing Record 17 | mataura
# Processing Record 18 | dongsheng
# Processing Record 19 | punta arenas
# Processing Record 20 | fureidis
# Processing Record 21 | barrow
# Processing Record 22 | fort walton beach
# Processing Record 23 | norman wells
# Processing Record 24 | torbay
# Processing Record 25 | ushuaia
# Processing Record 26 | esperance
# Processing Record 27 | mar del plata
# Processing Record 28 | taolanaro
# City not found. Try another city...
# Processing Record 29 | zhuhai
# Processing Record 30 | vestmannaeyjar
# Processing Record 31 | illoqqortoormiut
# City not found. Try another city...
# Processing Record 32 | serdobsk
# Processing Record 33 | lebu
# Processing Record 34 | fernandopolis
# Processing Record 35 | naze
# Processing Record 36 | cockburn town
# Processing Record 37 | batemans bay
# Processing Record 38 | mackay
# Processing Record 39 | khatanga
# Processing Record 40 | kodiak
# Processing Record 41 | balkanabat
# Processing Record 42 | vaini
# Processing Record 43 | dingle
# Processing Record 44 | lompoc
# Processing Record 45 | tsihombe
# City not found. Try another city...
# Processing Record 46 | tiksi
# Processing Record 47 | butaritari
# Processing Record 48 | yaan
# Processing Record 49 | aklavik
# Processing Record 50 | pedasi
# Processing Record 51 | souillac
# Processing Record 52 | karpathos
# Processing Record 53 | sorvag
# City not found. Try another city...
# Processing Record 54 | mangrol
# Processing Record 55 | killybegs
# Processing Record 56 | lerwick
# Processing Record 57 | vila velha
# Processing Record 58 | kuching
# Processing Record 59 | geraldton
# Processing Record 60 | port alfred
# Processing Record 61 | poum
# Processing Record 62 | atar
# Processing Record 63 | kuche
# City not found. Try another city...
# Processing Record 64 | kulhudhuffushi
# Processing Record 65 | puerto ayora
# Processing Record 66 | dikson
# Processing Record 67 | sorsk
# Processing Record 68 | chokurdakh
# Processing Record 69 | saint george
# Processing Record 70 | barpathar
# Processing Record 71 | saldanha
# Processing Record 72 | mandiana
# Processing Record 73 | qaanaaq
# Processing Record 74 | tuktoyaktuk
# Processing Record 75 | bambous virieux
# Processing Record 76 | broome
# Processing Record 77 | ulaangom
# Processing Record 78 | labuhan
# Processing Record 79 | greenwood
# Processing Record 80 | port elizabeth
# Processing Record 81 | saint-philippe
# Processing Record 82 | bredasdorp
# Processing Record 83 | jamestown
# Processing Record 84 | raiwind
# Processing Record 85 | rikitea
# Processing Record 86 | belushya guba
# City not found. Try another city...
# Processing Record 87 | east london
# Processing Record 88 | severo-kurilsk
# Processing Record 89 | amderma
# City not found. Try another city...
# Processing Record 90 | atuona
# Processing Record 91 | harper
# Processing Record 92 | pangoa
# Processing Record 93 | hami
# Processing Record 94 | faanui
# Processing Record 95 | kloulklubed
# Processing Record 96 | tayu
# Processing Record 97 | howard springs
# Processing Record 98 | te anau
# Processing Record 99 | lircay
# Processing Record 100 | zaysan
# Processing Record 101 | kihei
# Processing Record 102 | longyearbyen
# Processing Record 103 | eureka
# Processing Record 104 | leshukonskoye
# Processing Record 105 | provideniya
# Processing Record 106 | namibe
# Processing Record 107 | talaya
# Processing Record 108 | nanortalik
# Processing Record 109 | gimli
# Processing Record 110 | palabuhanratu
# City not found. Try another city...
# Processing Record 111 | acajutla
# Processing Record 112 | ahipara
# Processing Record 113 | saint-pierre
# Processing Record 114 | baherden
# Processing Record 115 | russkaya polyana
# Processing Record 116 | arman
# Processing Record 117 | georgetown
# Processing Record 118 | vernon
# Processing Record 119 | chuy
# Processing Record 120 | dudinka
# Processing Record 121 | saint-louis
# Processing Record 122 | carnarvon
# Processing Record 123 | boulder city
# Processing Record 124 | paragominas
# Processing Record 125 | husavik
# Processing Record 126 | chisinau
# Processing Record 127 | hobart
# Processing Record 128 | abonnema
# Processing Record 129 | constitucion
# Processing Record 130 | cherskiy
# Processing Record 131 | haibowan
# City not found. Try another city...
# Processing Record 132 | cagayan de tawi-tawi
# City not found. Try another city...
# Processing Record 133 | hilo
# Processing Record 134 | sao jose do rio pardo
# Processing Record 135 | amparafaravola
# Processing Record 136 | sakaraha
# Processing Record 137 | abu zabad
# Processing Record 138 | gunjur
# Processing Record 139 | ancud
# Processing Record 140 | kampong chhnang
# Processing Record 141 | santa rosalia
# Processing Record 142 | margate
# Processing Record 143 | san isidro
# Processing Record 144 | bontang
# Processing Record 145 | port macquarie
# Processing Record 146 | ayan
# Processing Record 147 | new norfolk
# Processing Record 148 | shubarkuduk
# Processing Record 149 | almaznyy
# Processing Record 150 | pachino
# Processing Record 151 | erenhot
# Processing Record 152 | jumla
# Processing Record 153 | manono
# Processing Record 154 | callaway
# Processing Record 155 | huambo
# Processing Record 156 | sokolo
# Processing Record 157 | kanniyakumari
# Processing Record 158 | alotau
# City not found. Try another city...
# Processing Record 159 | pangnirtung
# Processing Record 160 | port lincoln
# Processing Record 161 | payo
# Processing Record 162 | chagda
# City not found. Try another city...
# Processing Record 163 | tasiilaq
# Processing Record 164 | port hardy
# Processing Record 165 | buala
# Processing Record 166 | hay river
# Processing Record 167 | champerico
# Processing Record 168 | beringovskiy
# Processing Record 169 | namie
# Processing Record 170 | nikolskoye
# Processing Record 171 | maniitsoq
# Processing Record 172 | fortuna
# Processing Record 173 | hue
# Processing Record 174 | mollendo
# Processing Record 175 | srivardhan
# Processing Record 176 | umzimvubu
# City not found. Try another city...
# Processing Record 177 | thompson
# Processing Record 178 | keshan
# City not found. Try another city...
# Processing Record 179 | balikpapan
# Processing Record 180 | bocanda
# Processing Record 181 | kapaa
# Processing Record 182 | khrebtovaya
# Processing Record 183 | lac-megantic
# Processing Record 184 | kavieng
# Processing Record 185 | ulladulla
# Processing Record 186 | barentsburg
# City not found. Try another city...
# Processing Record 187 | sorland
# Processing Record 188 | san cristobal
# Processing Record 189 | kawana waters
# City not found. Try another city...
# Processing Record 190 | mocambique
# City not found. Try another city...
# Processing Record 191 | pinawa
# Processing Record 192 | victor harbor
# Processing Record 193 | port blair
# Processing Record 194 | castro
# Processing Record 195 | dujuma
# City not found. Try another city...
# Processing Record 196 | mys shmidta
# City not found. Try another city...
# Processing Record 197 | cazaje
# City not found. Try another city...
# Processing Record 198 | takeo
# Processing Record 199 | alunitdag
# City not found. Try another city...
# Processing Record 200 | klaksvik
# Processing Record 201 | el guayabo
# Processing Record 202 | santiago del estero
# Processing Record 203 | zeya
# Processing Record 204 | alta floresta
# Processing Record 205 | myrtle beach
# Processing Record 206 | morro bay
# Processing Record 207 | la ronge
# Processing Record 208 | thohoyandou
# Processing Record 209 | samusu
# City not found. Try another city...
# Processing Record 210 | labutta
# City not found. Try another city...
# Processing Record 211 | muli
# Processing Record 212 | caravelas
# Processing Record 213 | chulakivka
# Processing Record 214 | buta
# Processing Record 215 | omboue
# Processing Record 216 | sarakhs
# Processing Record 217 | zimovniki
# Processing Record 218 | saskylakh
# Processing Record 219 | neyshabur
# Processing Record 220 | faya
# Processing Record 221 | dunedin
# Processing Record 222 | bereda
# Processing Record 223 | maloshuyka
# City not found. Try another city...
# Processing Record 224 | deori
# Processing Record 225 | batticaloa
# Processing Record 226 | portland
# Processing Record 227 | vilhena
# Processing Record 228 | saint-francois
# Processing Record 229 | jalesar
# Processing Record 230 | arraial do cabo
# Processing Record 231 | la orilla
# Processing Record 232 | lagoa
# Processing Record 233 | sakaiminato
# Processing Record 234 | cabatuan
# Processing Record 235 | encruzilhada
# Processing Record 236 | kismayo
# Processing Record 237 | kuhdasht
# Processing Record 238 | sao filipe
# Processing Record 239 | vostok
# Processing Record 240 | kribi
# Processing Record 241 | bengkulu
# Processing Record 242 | porto santo
# Processing Record 243 | panguna
# Processing Record 244 | chifeng
# Processing Record 245 | yar-sale
# Processing Record 246 | pilar
# Processing Record 247 | mayo
# Processing Record 248 | pevek
# Processing Record 249 | kasama
# Processing Record 250 | salihorsk
# Processing Record 251 | troitsk
# Processing Record 252 | yumen
# Processing Record 253 | abiramam
# Processing Record 254 | ust-nera
# Processing Record 255 | yulara
# Processing Record 256 | bolungarvik
# City not found. Try another city...
# Processing Record 257 | kirakira
# Processing Record 258 | nizhneyansk
# City not found. Try another city...
# Processing Record 259 | chabahar
# Processing Record 260 | adre
# Processing Record 261 | samalaeulu
# City not found. Try another city...
# Processing Record 262 | khonuu
# City not found. Try another city...
# Processing Record 263 | lorengau
# Processing Record 264 | khudumelapye
# Processing Record 265 | tianpeng
# Processing Record 266 | segovia
# Processing Record 267 | tessalit
# Processing Record 268 | abu dhabi
# Processing Record 269 | shalinskoye
# Processing Record 270 | jalu
# Processing Record 271 | jiayuguan
# Processing Record 272 | santarem
# Processing Record 273 | wanaka
# Processing Record 274 | urdzhar
# City not found. Try another city...
# Processing Record 275 | chern
# Processing Record 276 | lugo
# Processing Record 277 | businga
# Processing Record 278 | dubrovnik
# Processing Record 279 | baraut
# Processing Record 280 | ponnani
# Processing Record 281 | alofi
# Processing Record 282 | lavrentiya
# Processing Record 283 | eyl
# Processing Record 284 | esmeraldas
# Processing Record 285 | ixtapa
# Processing Record 286 | lerdo
# Processing Record 287 | ponta delgada
# Processing Record 288 | ojinaga
# Processing Record 289 | pacific grove
# Processing Record 290 | nagothana
# Processing Record 291 | dzaoudzi
# Processing Record 292 | vetlanda
# Processing Record 293 | sentyabrskiy
# City not found. Try another city...
# Processing Record 294 | bur gabo
# City not found. Try another city...
# Processing Record 295 | izvoru berheciului
# Processing Record 296 | pozo colorado
# Processing Record 297 | hanna
# Processing Record 298 | fairbanks
# Processing Record 299 | kushiro
# Processing Record 300 | crixas
# Processing Record 301 | hithadhoo
# Processing Record 302 | narrabri
# Processing Record 303 | port pirie
# Processing Record 304 | manggar
# Processing Record 305 | hobyo
# Processing Record 306 | sawtell
# Processing Record 307 | richards bay
# Processing Record 308 | ribeira grande
# Processing Record 309 | paez
# Processing Record 310 | coahuayana
# Processing Record 311 | illapel
# Processing Record 312 | anicuns
# Processing Record 313 | saravan
# Processing Record 314 | requena
# Processing Record 315 | gudari
# Processing Record 316 | victoria
# Processing Record 317 | gao
# Processing Record 318 | hualmay
# Processing Record 319 | vangaindrano
# Processing Record 320 | mouzouras
# Processing Record 321 | chalchihuites
# Processing Record 322 | chiguayante
# Processing Record 323 | hovd
# Processing Record 324 | pisco
# Processing Record 325 | grand centre
# City not found. Try another city...
# Processing Record 326 | kruisfontein
# Processing Record 327 | belmonte
# Processing Record 328 | grand river south east
# City not found. Try another city...
# Processing Record 329 | oussouye
# Processing Record 330 | adrar
# Processing Record 331 | sabang
# Processing Record 332 | henties bay
# Processing Record 333 | dukat
# Processing Record 334 | kuryk
# Processing Record 335 | venkatagiri
# Processing Record 336 | airai
# Processing Record 337 | laguna
# Processing Record 338 | san patricio
# Processing Record 339 | rabo de peixe
# Processing Record 340 | weyburn
# Processing Record 341 | cotonou
# Processing Record 342 | tabuk
# Processing Record 343 | maningrida
# Processing Record 344 | taoudenni
# Processing Record 345 | kavaratti
# Processing Record 346 | huangmei
# Processing Record 347 | phan rang
# City not found. Try another city...
# Processing Record 348 | ippy
# Processing Record 349 | victoria point
# Processing Record 350 | zirandaro
# Processing Record 351 | pandan niog
# Processing Record 352 | nyurba
# Processing Record 353 | nizwa
# Processing Record 354 | attawapiskat
# City not found. Try another city...
# Processing Record 355 | yazman
# Processing Record 356 | gurupi
# Processing Record 357 | ilulissat
# Processing Record 358 | dumas
# Processing Record 359 | koungheul
# Processing Record 360 | porto walter
# Processing Record 361 | tomohon
# Processing Record 362 | rodrigues alves
# Processing Record 363 | bethel
# Processing Record 364 | tautira
# Processing Record 365 | hervey bay
# Processing Record 366 | kaitangata
# Processing Record 367 | touros
# Processing Record 368 | goundam
# Processing Record 369 | imeni poliny osipenko
# Processing Record 370 | mercedes
# Processing Record 371 | rocha
# Processing Record 372 | vila
# Processing Record 373 | cidreira
# Processing Record 374 | aki
# Processing Record 375 | guerrero negro
# Processing Record 376 | padang
# Processing Record 377 | palmer
# Processing Record 378 | kasiri
# Processing Record 379 | guarapari
# Processing Record 380 | dubai
# Processing Record 381 | haines junction
# Processing Record 382 | praxedis guerrero
# Processing Record 383 | nicoya
# Processing Record 384 | avanigadda
# Processing Record 385 | kasongo-lunda
# Processing Record 386 | binzhou
# Processing Record 387 | haveli
# Processing Record 388 | mansoa
# Processing Record 389 | teguldet
# Processing Record 390 | iwanai
# Processing Record 391 | narsaq
# Processing Record 392 | turukhansk
# Processing Record 393 | ullapool
# Processing Record 394 | charters towers
# Processing Record 395 | ust-bolsheretsk
# City not found. Try another city...
# Processing Record 396 | atasu
# Processing Record 397 | nathdwara
# Processing Record 398 | rampur hat
# Processing Record 399 | aljezur
# Processing Record 400 | crnomelj
# Processing Record 401 | nemuro
# Processing Record 402 | ulagan
# Processing Record 403 | los llanos de aridane
# Processing Record 404 | zhoucheng
# Processing Record 405 | oksfjord
# Processing Record 406 | troitsko-pechorsk
# Processing Record 407 | itarema
# Processing Record 408 | sumbe
# Processing Record 409 | haifa
# Processing Record 410 | port-gentil
# Processing Record 411 | hasaki
# Processing Record 412 | caborca
# Processing Record 413 | vardo
# Processing Record 414 | tazovskiy
# Processing Record 415 | honningsvag
# Processing Record 416 | nuuk
# Processing Record 417 | kedrovyy
# Processing Record 418 | coquimbo
# Processing Record 419 | sur
# Processing Record 420 | erie
# Processing Record 421 | aflu
# City not found. Try another city...
# Processing Record 422 | sao joao da barra
# Processing Record 423 | ruatoria
# City not found. Try another city...
# Processing Record 424 | mount gambier
# Processing Record 425 | lufilufi
# Processing Record 426 | srednekolymsk
# Processing Record 427 | bonfim
# Processing Record 428 | effingham
# Processing Record 429 | lebyazhye
# Processing Record 430 | bilma
# Processing Record 431 | temaraia
# City not found. Try another city...
# Processing Record 432 | pecos
# Processing Record 433 | shakiso
# Processing Record 434 | tyler
# Processing Record 435 | tornio
# Processing Record 436 | ondjiva
# Processing Record 437 | ler
# Processing Record 438 | north platte
# Processing Record 439 | vestbygda
# City not found. Try another city...
# Processing Record 440 | beatrice
# Processing Record 441 | pandan
# Processing Record 442 | hasilpur
# Processing Record 443 | tiznit
# Processing Record 444 | karratha
# Processing Record 445 | sulangan
# Processing Record 446 | luanda
# Processing Record 447 | ribeira brava
# Processing Record 448 | olafsvik
# Processing Record 449 | kongolo
# Processing Record 450 | auki
# Processing Record 451 | donskoy
# Processing Record 452 | tarakan
# Processing Record 453 | livingston
# Processing Record 454 | bagdarin
# Processing Record 455 | seoni
# Processing Record 456 | dubuque
# Processing Record 457 | shakawe
# Processing Record 458 | paamiut
# Processing Record 459 | dosso
# Processing Record 460 | nouadhibou
# Processing Record 461 | wadi maliz
# Processing Record 462 | marcona
# City not found. Try another city...
# Processing Record 463 | asuncion
# Processing Record 464 | rosario
# Processing Record 465 | bandarbeyla
# Processing Record 466 | tuatapere
# Processing Record 467 | khairpur nathan shah
# Processing Record 468 | hamilton
# Processing Record 469 | shimoda
# Processing Record 470 | flinders
# Processing Record 471 | bhindar
# Processing Record 472 | zhanaozen
# Processing Record 473 | tigzirt
# Processing Record 474 | karakendzha
# City not found. Try another city...
# Processing Record 475 | opuwo
# Processing Record 476 | cabo san lucas
# Processing Record 477 | luderitz
# Processing Record 478 | antimakhia
# City not found. Try another city...
# Processing Record 479 | gigmoto
# Processing Record 480 | fort nelson
# Processing Record 481 | molina
# Processing Record 482 | teguise
# Processing Record 483 | sidi ali
# Processing Record 484 | muroto
# Processing Record 485 | belaya gora
# Processing Record 486 | karkaralinsk
# City not found. Try another city...
# Processing Record 487 | brazzaville
# Processing Record 488 | itanhaem
# Processing Record 489 | kamiiso
# Processing Record 490 | bokoro
# Processing Record 491 | manzil tamim
# City not found. Try another city...
# Processing Record 492 | comodoro rivadavia
# Processing Record 493 | brae
# Processing Record 494 | vanavara
# Processing Record 495 | felanitx
# Processing Record 496 | tete
# Processing Record 497 | taunggyi
# Processing Record 498 | iqaluit
# Processing Record 499 | kurumkan
# Processing Record 500 | north battleford
# Processing Record 501 | swellendam
# Processing Record 502 | umm lajj
# Processing Record 503 | itoman
# Processing Record 504 | nishihara
# Processing Record 505 | xingyi
# Processing Record 506 | huallanca
# Processing Record 507 | sipovo
# Processing Record 508 | mildura
# Processing Record 509 | puerto del rosario
# Processing Record 510 | oranjestad
# Processing Record 511 | ashcroft
# Processing Record 512 | russell
# Processing Record 513 | tubmanburg
# Processing Record 514 | katsuura
# Processing Record 515 | mount isa
# Processing Record 516 | samaipata
# Processing Record 517 | axim
# Processing Record 518 | honiara
# Processing Record 519 | alice town
# Processing Record 520 | rio gallegos
# Processing Record 521 | itacare
# Processing Record 522 | erzin
# Processing Record 523 | egvekinot
# Processing Record 524 | baykit
# Processing Record 525 | tura
# Processing Record 526 | dawei
# Processing Record 527 | miyako
# Processing Record 528 | kachikau
# City not found. Try another city...
# Processing Record 529 | along
# Processing Record 530 | mahwa
# Processing Record 531 | zdunska wola
# Processing Record 532 | llanes
# Processing Record 533 | vadgaon
# Processing Record 534 | calabozo
# Processing Record 535 | yazd
# Processing Record 536 | cam pha
# City not found. Try another city...
# Processing Record 537 | silopi
# Processing Record 538 | dedovichi
# Processing Record 539 | midland
# Processing Record 540 | tarbes
# Processing Record 541 | sitka
# Processing Record 542 | barahona
# Processing Record 543 | karaul
# City not found. Try another city...
# Processing Record 544 | pekan
# Processing Record 545 | dharchula
# Processing Record 546 | koumac
# Processing Record 547 | ranot
# Processing Record 548 | camacha
# Processing Record 549 | ati
# Processing Record 550 | banning
# Processing Record 551 | royan
# Processing Record 552 | bay-khaak
# Processing Record 553 | lloydminster
# Processing Record 554 | iquique
# Processing Record 555 | copiapo
# Processing Record 556 | kandalaksha
# Processing Record 557 | anadyr
# Processing Record 558 | necochea
# Processing Record 559 | cayenne
# Processing Record 560 | lazaro cardenas
# Processing Record 561 | clyde river
# Processing Record 562 | belyy yar
# Processing Record 563 | tubuala
# Processing Record 564 | ahuimanu
# Processing Record 565 | leningradskiy
# Processing Record 566 | gumushane
# City not found. Try another city...
# Processing Record 567 | presidente medici
# Processing Record 568 | grand-santi
# Processing Record 569 | vanimo
# Processing Record 570 | mecca
# Processing Record 571 | muscat
# Processing Record 572 | viedma
# Processing Record 573 | wanning
# Processing Record 574 | abu samrah
# Processing Record 575 | tuzha
# Processing Record 576 | stornoway
# Processing Record 577 | mocuba
# Processing Record 578 | ingham
# Processing Record 579 | barabai
# Processing Record 580 | anjozorobe
# Processing Record 581 | benghazi
# Processing Record 582 | talcahuano
# Processing Record 583 | goianapolis
# Processing Record 584 | rock sound
# Processing Record 585 | belawan
# Processing Record 586 | vila franca do campo
# Processing Record 587 | sao jose da coroa grande
# Processing Record 588 | ketchikan
# Processing Record 589 | lakatoro
# Processing Record 590 | meadow lake
# Processing Record 591 | grandview
# Processing Record 592 | tambura
# Processing Record 593 | poindimie
# Processing Record 594 | rio grande
# Processing Record 595 | retz
# Processing Record 596 | hohhot
# Processing Record 597 | jiaxing
# Processing Record 598 | chicama
# Processing Record 599 | bauska
# Processing Record 600 | gazli
# Processing Record 601 | sunrise manor
# Processing Record 602 | varniai
# Processing Record 603 | burriana
# Processing Record 604 | brahmapuri
# City not found. Try another city...
# Processing Record 605 | constantine
# Processing Record 606 | evensk
# Processing Record 607 | puerto rondon
# Processing Record 608 | barabash
# Processing Record 609 | yarmouth
# Processing Record 610 | krasnosilka
# Processing Record 611 | codrington
# Processing Record 612 | sangar
# Processing Record 613 | ulaanbaatar
# Processing Record 614 | vokhtoga
# Processing Record 615 | whitefish
# Processing Record 616 | kiunga
# Processing Record 617 | bargal
# City not found. Try another city...
# Processing Record 618 | miri
# Processing Record 619 | yaring
# Processing Record 620 | okha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data_df = pd.DataFrame(data)
data_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  ponta do sol          75      PT  1601342873        82  32.67  -17.10
# 1     busselton         100      AU  1601342873        94 -33.65  115.33
# 2        albany           0      US  1601342874        84  42.60  -73.97
# 3     cape town           9      ZA  1601342874        93 -33.93   18.42
# 4      zhigansk         100      RU  1601342875        95  66.77  123.37
#
#    Max Temp  Wind Speed
# 0     20.00        6.20
# 1     16.11        2.68
# 2     22.22        3.23
# 3     12.22        2.10
# 4      1.54       11.27

# %%
# Output File (CSV)
data_df.to_csv("../output_data/weather_output.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
data_df.plot(kind='scatter', figsize=(10, 6), x='Lat',y='Max Temp', color="green",title='City Latitude vs. Temperature (3/15/2020)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(b=True)
plt.savefig("../Images/Lat_Temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
data_df.plot(kind='scatter',figsize=(10, 6), x='Lat',y='Humidity',color="green", title='City Latitude vs. Humidity (3/15/2020)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b=True)
plt.savefig("../Images/Lat_Humid.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
data_df.plot(kind='scatter', figsize=(10, 6), x='Lat',y='Cloudiness',color="green", title='City Latitude vs. Cloudiness (3/15/2020)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b=True)
plt.savefig("../Images/Lat_Cloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
data_df.plot(kind='scatter', figsize=(10, 6), x='Lat',y='Wind Speed', color="green",title='City Latitude vs. Wind Speed (3/15/2020)')
plt.xlabel('Latitude')
plt.ylabel(' Wind Speed (km/h)')
plt.grid(b=True)
plt.savefig("../Images/Lat_Wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
result= st.linregress(data_df["Lat"], data_df["Max Temp"])
result
# Out:
# LinregressResult(slope=-0.10019787982419875, intercept=20.19902032753247, rvalue=-0.35868942365164624, pvalue=1.1728493898659568e-18, stderr=0.010970086079643568)

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linreg(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x.astype(float), y.astype(float))
    regress_values = x.astype(float) * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y, edgecolors = "green")
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(x.min(),y.max()),fontsize=12,color="red")
    print(f'The r-squared is: {rvalue}')

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = data_df.loc[data_df["Lat"] >= 0]
southern_df = data_df.loc[data_df["Lat"] <= 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.figure(figsize=(10, 6))
linreg(northern_df["Lat"], northern_df["Max Temp"])
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.savefig("../Images/NH_lat_vs_temp.png")
plt.show()
# Out:
# The r-squared is: -0.8343537623851165

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.figure(figsize=(10, 6))
linreg(southern_df["Lat"], southern_df["Max Temp"])
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.savefig("../Images/SH_lat_vs_temp.png")
# Out:
# The r-squared is: 0.7491744304739749

# %% [markdown]
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(10, 6))
linreg(northern_df["Lat"], northern_df["Humidity"])
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.savefig("../Images/NH_lat_vs_humid.png")
# Out:
# The r-squared is: 0.03464692315509804

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(10, 6))
linreg(southern_df["Lat"], southern_df["Humidity"])
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.savefig("../Images/SH_lat_vs_humid.png")
# Out:
# The r-squared is: 0.03407142954757836

# %% [markdown]
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(10, 6))
linreg(northern_df["Lat"], northern_df["Cloudiness"])
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.savefig("../Images/NH_lat_vs_cloudiness.png")
# Out:
# The r-squared is: 0.03316909316377324

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(10, 6))
linreg(southern_df["Lat"], southern_df["Cloudiness"])
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.savefig("../Images/SH_lat_vs_cloudiness.png")
# Out:
# The r-squared is: -0.005887582400261361

# %% [markdown]
# The low r values indicate that there is no real relationship between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(10, 6))
linreg(northern_df["Lat"], northern_df["Wind Speed"])
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")
plt.ylabel("Wind Speed (km/h)")
plt.xlabel("Latitude")
plt.savefig("../Images/NH_lat_vs_wind.png")
# Out:
# The r-squared is: 0.20850108274559592

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(10, 6))
linreg(southern_df["Lat"], southern_df["Wind Speed"])
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")
plt.ylabel("Wind Speed (km/h)")
plt.xlabel("Latitude")
plt.savefig("../Images/NH_lat_vs_wind.png")
# Out:
# The r-squared is: -0.27888598083523297

# %% [markdown]
# The low r values indicate that there is no real relationship between wind speed and latitude." The difference between the hemispheres doesn't seem to be significant enough to comment upon.
